# %% [markdown]
# # Cyton Session Post-Processing

# %% [markdown]
# ## Preprocessing
# s
# ### Remove DC offset, bandpass filter, and notch filter
#
# ### Feature Extraction

# %%
import neurokit2 as nk

# %%
data = nk.data("bio_eventrelated_100hz")
data
# Out:
#             ECG        EDA  Photosensor       RSP
# 0     -0.015869  13.196868          5.0  0.778931
# 1     -0.011703  13.197173          5.0  0.777588
# 2     -0.009766  13.197020          5.0  0.777435
# 3     -0.013321  13.197631          5.0  0.777557
# 4     -0.009583  13.196715          5.0  0.775299
# ...         ...        ...          ...       ...
# 14995 -0.007675  14.873656          5.0  1.351868
# 14996 -0.005203  14.873961          5.0  1.356689
# 14997 -0.004272  14.874266          5.0  1.361938
# 14998 -0.000458  14.875335          5.0  1.366821
# 14999  0.000244  14.874114          5.0  1.372040
#
# [15000 rows x 4 columns]

# %%
ecg = data["ECG"]
ecg
# Out:
# 0       -0.015869
# 1       -0.011703
# 2       -0.009766
# 3       -0.013321
# 4       -0.009583
#            ...
# 14995   -0.007675
# 14996   -0.005203
# 14997   -0.004272
# 14998   -0.000458
# 14999    0.000244
# Name: ECG, Length: 15000, dtype: float64

# %%
# Preprocess the data (filter, find peaks, etc.)
processed_data, info = nk.bio_process(
    ecg=data["ECG"], rsp=data["RSP"], eda=data["EDA"], sampling_rate=100
)

# %%
# Compute relevant features
results = nk.bio_analyze(processed_data, sampling_rate=100)
results
# Out:
#   ECG_Rate_Mean             HRV_MeanNN               HRV_SDNN HRV_SDANN1  \
# 0     60.896029  [[985.8940397350993]]  [[84.92562646754557]]    [[nan]]
#
#   HRV_SDNNI1 HRV_SDANN2 HRV_SDNNI2 HRV_SDANN5 HRV_SDNNI5  \
# 0    [[nan]]    [[nan]]    [[nan]]    [[nan]]    [[nan]]
#
#                HRV_RMSSD  ... EDA_SympatheticN EDA_Autocorrelation  \
# 0  [[72.92461861401813]]  ...         0.001729            0.366741
#
#   RSA_P2T_Mean RSA_P2T_Mean_log RSA_P2T_SD RSA_P2T_NoRSA RSA_PorgesBohrer  \
# 0    91.025641         4.511141   69.08404           0.0        -5.647619
#
#   RSA_Gates_Mean RSA_Gates_Mean_log RSA_Gates_SD
# 0        8.43424             2.1323     0.167729
#
# [1 rows x 137 columns]
